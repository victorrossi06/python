# %%
# Estrutura com recursão
def it(n):
    if n == 0:
        return 1
    return n * it ( n - 1 )

it()
# Out:
# 815915283247897734345611269596115894272000000000

# %%
# Estrutura com repetição

def it(n):

    result = 1
    for i in range(1, n+1):
        result *= i

    return result
# %time it(500)
# Out:
# CPU times: total: 0 ns
# Wall time: 48.2 μs
# ...
